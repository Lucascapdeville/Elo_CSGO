# %%
import pandas as pd

# %%
elo = pd.read_csv('data/Teams_elo.csv',sep = ';',index_col=0)
# Out:
#               date        team1               team2          map  \
# 0       2012-01-11     gamed!de               iPLAY     Train_se
# 1       2012-01-11        CPLAY           dotpiXels    Mirage_ce
# 2       2012-01-11        CPLAY     ALTERNATE aTTaX     Train_se
# 3       2012-01-12    VeryGames                 dAT      Nuke_se
# 4       2012-01-12      zNation  Brussels Guardians   Inferno_se
# ...            ...          ...                 ...          ...
# 104399  2021-12-26    INDE IRAE                 DNG         Nuke
# 104400  2021-12-26           B8              IKIGAI      Ancient
# 104401  2021-12-26           B8              IKIGAI       Mirage
# 104402  2021-12-26    INDE IRAE                 DNG       Mirage
# 104403  2021-12-26  Team StRoGo          Team Shoke      Ancient
#
#                                             event event_type event_tier  s1  \
# 0       ESL Pro Series Germany Winter Season 2012     Online          B  16
# ...
